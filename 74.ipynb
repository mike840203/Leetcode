# %%
matrix = [[1,   3,  5,  7],[10, 11, 16, 20],[23, 30, 34, 50]]
target = 1
out = False
for x in range(len(matrix)) :
    if target in matrix[x] : out = True
print out
# Out:
# True

# %%
matrix = [[1,   3,  5,  7],[10, 11, 16, 20],[23, 30, 34, 50]]
for i in matrix :
    print i
# Out:
# [1, 3, 5, 7]
# [10, 11, 16, 20]
# [23, 30, 34, 50]

# %%
column = [matrix[i][0] for i in range(len(matrix))]
column
# Out:
# [1, 10, 23]

# %%
x = [1,2,5,7,9,10,12,15,19,20]
target = 18
def binary(list,target) :
    head , tail = 0 , len(list)
    while head < tail :
        print head , tail
        if target > list[(head+tail)/2] :
            head , tail = (head+tail)/2 , tail
        elif target < list[(head+tail)/2] :
            head , tail = head , (head+tail)/2
        else :
            return (head+tail)/2
        if head + 1 == tail:
            break
    return head
binary(x,target)
# Out:
# 0 10
# 5 10
# 7 10
# 7

# %%
for target in range(51) :
    y = binary(column,target)  
    x = binary(matrix[y],target)  
    if target == matrix[y][x] :
        print target
    else :
        pass
# Out:
# 1
# 3
# 5
# 7
# 10
# 11
# 16
# 20
# 23
# 30
# 34
# 50
