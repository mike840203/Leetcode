# %%
s = "A man, a plan, a canal: Panama"
ss = ''
for i in range(len(s)) :
    if ord(s[i]) >= ord("A") and ord(s[i]) <= ord("Z") :
        ss = ss + chr(ord(s[i])+32)
    elif ord(s[i]) >= ord("a") and ord(s[i]) <= ord("z") :
        ss = ss + s[i]
    elif ord(s[i]) >= ord("0") and ord(s[i]) <= ord("9") :
        ss = ss + s[i]
    else :
        pass
print True if ss == ss[::-1] else False
# TLE
# Out:
# True

# %%
s = (" ").lower()
s = s.lower()
head = 0
tail = len(s) - 1
flaghead = 0
flagtail = 0
flag = 1
def certify(charac) :
    if  ord(charac) >= ord("A") and ord(charac) <= ord("Z") or ord(charac) >= ord("a") and ord(charac) <= ord("z") or ord(charac) >= ord("0") and ord(charac) <= ord("9") :
        return True
    else :
        return False
while head < tail :
    if certify(s[head]) : 
        flaghead = 1
    else :
        head += 1
    if certify(s[tail]) :
        flagtail = 1
    else :
        tail -= 1 
    if flaghead == flagtail and flaghead != 0 :
        if ord(s[head]) != ord(s[tail])  :
            print False
        flag = 1
        head += 1
        tail -= 1
        flaghead = 0
        flagtail = 0
if flag == 0 :
    print False
print True
# pass but fucking slow
# Out:
# False
# True

# %%
s = "A man, a plan, a canal: Panama"
new = [i for i in s.lower() if i.isalnum()]
print new == new[::-1]
# Out:
# True

# %%
# Out:
# a man, a plan, a canal: panama
