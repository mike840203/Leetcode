# %%
nums = [2, 3, 5, 1, 12]
for i in range(len(nums)) :
    print '******'
    for j in range(i+1,len(nums)) :
        if nums[i] == 0 and nums[j] != 0 :
            temp = nums[j]
            nums[j] = nums[i]
            nums[i] = temp
            break
print nums
# Out:
# ******
# ******
# ******
# ******
# ******
# [2, 3, 5, 1, 12]
