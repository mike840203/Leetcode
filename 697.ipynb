# %%
nums = [1]
out = []
outvalue = 100000
max_count = 0
maxlist = {}
start = {}
end = {}
for i in range(len(nums)) :
    if nums[i] not in start.keys() :
        maxlist[nums[i]] = 1
        start[nums[i]] = i 
        end[nums[i]] = i
        max_count = max(max_count,maxlist[nums[i]])
    else :
        maxlist[nums[i]] += 1
        end[nums[i]] = i
        max_count = max(max_count,maxlist[nums[i]])
print start
print maxlist
print end
print max_count
for i in maxlist.keys() :
    if max_count == maxlist[i] :
        out.append(i)
print out
for i in range(len(out)) :
    outvalue = min( outvalue, end[out[i]] - start[out[i]] + 1 )
print outvalue
# Out:
# {1: 0}
# {1: 1}
# {1: 0}
# 1
# [1]
# 1

# %%
nums = [1]
out = []
outvalue = 100000
max_count = 0
maxlist = {}
start = {}
end = {}
for i in range(len(nums)) :
    if nums[i] not in start.keys() :
        maxlist[nums[i]] = 1
        start[nums[i]] = i 
        end[nums[i]] = i
        max_count = max(max_count,maxlist[nums[i]])
    else :
        maxlist[nums[i]] += 1
        end[nums[i]] = i
        max_count = max(max_count,maxlist[nums[i]])
for i in maxlist.keys() :
    if max_count == maxlist[i] :
        out.append(i)
for i in range(len(out)) :
    outvalue = min( outvalue, end[out[i]] - start[out[i]] + 1 )
print outvalue
# Out:
# 100000
