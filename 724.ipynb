# %%
import timeit
start = timeit.default_timer()
nums = [-1,-1,-1,1,1,1,0]
i = 0 
L = 0
R = sum(nums[i+1::])
while i <= len(nums) - 1 :
    if i != 0 :
        L = L + nums[i-1]
        R = R - nums[i]
    if L == R :
        print i 
    i = i + 1
print -1
stop = start = timeit.default_timer()
print '花費時間 :' + str(round((stop - start)*1000,4)) + 'ms'
# Out:
# 6
# -1
# 花費時間 :0.0ms
