# %%
chars = ["a","b","b","b","b","b","b","b","b","b","b","b","b"]
slow = 0
index = 1
temp = ''
for fast in range(len(chars)) :
    if temp == '' :
        temp = chars[fast]
        chars[slow] = temp
        slow += 1
    elif temp != chars[fast] :
        if index > 1 :
            if index / 10 > 0 :
                chars[slow] = str(index/10)
                index = index % 10
                slow += 1 
            chars[slow] = str(index)
            index = 1
            slow += 1 
        temp = chars[fast]
        chars[slow] = temp
        slow += 1
    else :
        index += 1
    if fast == len(chars) - 1 and slow <= fast and index > 1 :
        if index / 10 > 0 :
            chars[slow] = str(index/10)
            index = index % 10
            slow += 1 
        chars[slow] = str(index)
        slow = slow + 1

print slow    
print chars
# Out:
# 4
# ['a', 'b', '1', '2', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b']
