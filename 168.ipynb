# %%
n = 28
out = ''
def cal(n,out) :
    print n
    if n > 26 :
        if n % 26 == 0 :
            out = out + chr(64+26)
            n = ( ( n - n % 26 ) / 26 ) - 1
        else : 
            out = out + chr(64+n%26)
            n = ( n - n % 26 ) / 26 
        return cal(n,out)
    else :
        out = out + chr(64+n)
        return out
print cal(n,out)[::-1]
# Out:
# 28
# 1
# AB
