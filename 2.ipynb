# %%
x = [2,4,3]
y = [5,6,4]
outx = ""
outy = ""
outlist = []
for i in range(len(x)) :
    outx = outx + str(x[i])
for i in range(len(y)) :
    outy = outy + str(y[i])
print outx
print outy
out = str(int(outx[::-1]) + int(outy[::-1]))
out = out[::-1]
for i in range(len(out)) :
    outlist.append(out[i])
print outlist
# Out:
# 243
# 564
# ['7', '0', '8']

# %%
x = ListNode(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3995893c6530> in <module>()
# ----> 1 x = ListNode(3)
#
# NameError: name 'ListNode' is not defined
