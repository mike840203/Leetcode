# %%
num = 13
dictx = {}
stander = [2,3,5]
if num == 1 : print True
if num < 1  : print False
def getPrimeNum(num,dictx) :
    thisdict = 0
    for i in range(2, int((num ** 0.5) )+ 1 ) :
        if num % i == 0 :
            thisdict = 1
            num = num / i
            if i not in dictx : 
                dictx[i] = 1
            else : 
                dictx[i] += 1
            return getPrimeNum(num,dictx)
        if i == int( (num ** 0.5) ) and thisdict == 0 :
            dictx[num] = 1
    if num == 2 or num == 3 :
        if num not in dictx : 
            dictx[num] = 1
        else : 
            dictx[num] += 1
    return dictx
#print getPrimeNum(num,dictx)
for i in dictx.keys() :
    if i not in stander :
        print False
# Out:
# {13: 1}
# False

# %%
stander = [2,3,5]
x = {1:2,2:30}
print x in stander
for i in x.keys() :
    print i in stander
# Out:
# False
# False
# True
