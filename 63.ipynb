# %%
matrix = [[0,0,0],[0,1,0],[0,0,0]]
def uniquePathsWithObstacles(obstacleGrid):
    if len(matrix) == 0 : return 0
    y , x = len(matrix) , len(matrix[0])
    for j in range(y) :
        for i in range(x) :
            if j == 0 and i == 0 and matrix[j][i] == 0 : 
                matrix[j][i] = 1
            elif matrix[j][i] == 1 :
                matrix[j][i] = 0
            else :
                tempy = matrix[j-1][i] if j-1 >= 0 else 0
                tempx = matrix[j][i-1] if i-1 >= 0 else 0 
                matrix[j][i] = tempx + tempy
    return matrix[j][i]
uniquePathsWithObstacles(matrix)
# Out:
# 2

# %%
matrix = [[0,0,0],[0,1,0],[0,0,0]]
def uniquePathsWithObstacles(matrix):
    if len(matrix) == 0 : return 0
    y , x = len(matrix) , len(matrix[0])
    mat = [[0 for i in range(x)]for j in range(y)]
    for j in range(y) :
        for i in range(x) :
            if j == 0 and i == 0 and matrix[j][i] == 0 : 
                mat[j][i] = 1
            elif matrix[j][i] == 1 :
                mat[j][i] = 0
            else :
                mat[j][i] = mat[j-1][i] + mat[j][i-1]
    for q in mat :
        print q
    return mat[j][i]
uniquePathsWithObstacles(matrix)
