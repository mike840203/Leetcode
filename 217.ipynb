# %%
nums = [1,2,1,2,5,5,4,6,4,2,8]
dict = {}
out = False
for i in nums :
    if i in dict :
        dict[i] += 1
        if dict[i] > 1 :
            print True
    else :
        dict[i] = 1
print False
# Out:
# True
# True
# True
# True
# True
# False
