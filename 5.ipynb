# %%
def calpalindromic(string,left,right) :
    temp = ''
    while left >= 0 and right < len(string) and s[left] == s[right] :
        left -= 1
        right += 1
    #print 'left = ' + str(left)
    #print 'right = ' + str(right)
    if len(temp) < right - left + 1 :
        temp = s[left+1:right]
    #print 'temp = ' + str(temp)
    return temp
    
s = '"cbfbaac"'    
if len(s) == 0 : print s
ma = ''
for i in range(len(s)) :
    curr1 = calpalindromic(s,i,i) 
    curr2 = calpalindromic(s,i,i+1) 
    temp = curr1 if len(curr1) > len(curr2) else curr2
    ma = temp if len(temp) > len(ma) else ma
    #print
print ma
# Out:
# bfb
