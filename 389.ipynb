# %%
s = "ee"
t = "e"
dictlong = {}
[ longNum , shortNum ]= [t,s] if len(t) > len(s) else [s,t]
for element in longNum :
    if element not in dictlong :
        dictlong[element] = 1
    else : 
        dictlong[element] += 1
for element in shortNum :
    dictlong[element] -= 1
for key in dictlong.keys() :
    if dictlong[key] != 0 :
        print key
# Out:
# e
