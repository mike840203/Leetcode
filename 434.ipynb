# %%
s = "k k"
print len(s.split())
# Out:
# 2

# %%
sum(True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-160ebad86e05> in <module>()
# ----> 1 sum(True)
#
# TypeError: 'bool' object is not iterable
