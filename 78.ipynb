# %%
nums = [1,2,3]
def back(numlist, out = []) :
    print out
    if len(numlist) == 1 :
        return out
    elif len(numlist) > 1 :
        for i in range(len(numlist)) :
            temp = numlist[0:i] + numlist[i+1:]
            #print temp
            back(temp,temp)
    out.append([])
    return out
back(nums)
# Out:
# []
# [2, 3]
# [2, 3, 3]
# [2, 3, 2]
# [1, 3]
# [1, 3, 3]
# [1, 3, 1]
# [1, 2]
# [1, 2, 2]
# [1, 2, 1]
# [[]]
