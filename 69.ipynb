# %%
x = 2147395599

def mul(num,n,times) :
    if times != 1 :
        return mul(n*num,n,times-1)
    else :
        return num
    
for i in range((x/2)+1,1,-1) :
    index = 2
    while mul(i,i,index) <= x :
        if mul(i,i,index) == x :
            print i
            break
        else :
            index = index + 1
    if i == 2 :
        print 'None'

# %%
def mul(num,n,times) :
    if times != 1 :
        return mul(n*num,n,times-1)
    else :
        return num
print mul(2,2,4)
# Out:
# 16

# %%
x = [4,4,4,4,10]
y = [4,4,4,4,8]
x.remove(x[len(x)-1])
print x
# Out:
# [4, 4, 4, 4]
