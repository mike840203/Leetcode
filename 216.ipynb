# %%
k = 3
n = 7

# %%
def back(k,n,ans,res) :
    print hex(id(ans))
    if  k == 0 :
        if n == 0 and list(set(ans)) not in res :
            x = ans
            print hex(id(list(x)))
            print 
            res.append((x))
            print res
            pass
        else :
            pass
    else :
        for i in range(1,n+1) :
            if i not in ans :
                ans.append(i)
                back(k-1,n-i,ans,res)
                ans.remove(i)
            else :
                pass

# %%
l = []
print hex(id(l))
back(k,n,[],l) 
print l
# Out:
# 0x8342f08L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x83a0248L
#
# [[1, 2, 4]]
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c908L
#
# [[1, 4, 2], [1, 4, 2]]
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c848L
#
# [[2, 1, 4], [2, 1, 4], [2, 1, 4]]
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c588L
#
# [[2, 4, 1], [2, 4, 1], [2, 4, 1], [2, 4, 1]]
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c988L
#
# [[4, 1, 2], [4, 1, 2], [4, 1, 2], [4, 1, 2], [4, 1, 2]]
# 0x839c308L
# 0x839c308L
# 0x839ca08L
#
# [[4, 2, 1], [4, 2, 1], [4, 2, 1], [4, 2, 1], [4, 2, 1], [4, 2, 1]]
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# 0x839c308L
# [[], [], [], [], [], []]
