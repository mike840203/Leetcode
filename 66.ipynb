# %%
digits = []
tempstr = ''
tempint = 0
out = []
if len(digits) == 0 :
    out.append(1)
else :
    for i in range(len(digits)) :
        tempstr = tempstr + str(digits[i])
    tempstr = str(int(tempstr) + 1)
    for i in range(len(tempstr)) :
        out.append(int(tempstr[i]))
print out
# Out:
# [1]
