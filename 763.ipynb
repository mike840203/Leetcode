# %%
S = "ababcbacadefegdehijhklij"
dict = {}
for index, element in enumerate(S) :
    if element not in dict.keys() :
        dict[element] = [index, index]
    else :
        dict[element][1] = index
list = sorted(dict.values())
print list
count = 0
while(count<=len(list)-2) :
    if list[count][1] >= list[count+1][1] :
        del list[count+1]
    elif list[count][1] <= list[count+1][0] :
        count = count + 1
    else :
        list.insert(count+2,[list[count][0],list[count+1][1]])
        del list[count]
out = []
print list
for element in list :
    out.append(element[1]-element[0]+1)
print out
# Out:
# [[0, 8], [1, 5], [4, 7], [9, 14], [10, 15], [11, 11], [13, 13], [16, 19], [17, 22], [18, 23], [20, 20], [21, 21]]
# [[0, 8], [10, 15], [18, 23]]
# [9, 6, 6]
