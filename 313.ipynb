# %%
num = 12
primes = [2, 7, 13, 19]
mi = 1
count = 1
index = 0
li = [1]
listx = [0] * len(primes)   #存數字
indexlistx = [0] * len(primes) # 存index
while count < num :
    for i in range(len(primes)) :
        listx[i] = primes[i] * li[indexlistx[i]]
    mi = min(listx)
    for i in range(len(primes)) :
        if mi == listx[i] :
            indexlistx[i] += 1 
    li.append(mi)
    count += 1
print mi
# Out:
# 32
