# %%
points = [[1,0],[2,0],[0,0]]

def distant(point1,point2) :
    return ( (point1[0]-point2[0])**2 + (point1[1]-point2[1])**2 ) ** 0.5
for i in range(len(points)) :
    for j in range(i+1,len(points)) :
# Out:
#   File "<ipython-input-1-94b6e78996cd>", line 6
#     for j in range(i+1,len(points))
#                                    ^
# SyntaxError: invalid syntax
