# %%
s = "cars"
wordDict = ["car", "ca", "rs"]
out = True
offset = 0 
while s != '' :
    flag = False
    for i in range(len(wordDict)) :
        if s[offset:len(wordDict[i])] == wordDict[i] :
            s = s[len(wordDict[i])::]
            flag = True
            break
    if  flag == False :
        out = False
        break
print out
# Should be True
# Out:
# False

# %%
s = "cars"
wordDict = ["car", "ca", "rs"]
def cal(s,wordDict) :
    
    
cal(s,wordDict)
# Out:
# d
