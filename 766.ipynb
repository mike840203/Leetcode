# %%
matrix = [[1,2,3,5],[5,1,2,3],[92,5,21,25]]
i = len(matrix)
j = len(matrix[0])
c = 0
if i <= 1 or j <= 1 :
    print True
for x in range(j) :
    for y in range(i) :
        if x == 0 or y == 0 :
            c = c + 1 
            tempx = x 
            tempy = y
            while tempx < j - 1 and tempy < i - 1 :
                if matrix[tempy][tempx] != matrix[tempy+1][tempx+1] :
                    print False
                tempx = tempx + 1
                tempy = tempy + 1
print c
# Out:
# False
# False
# 6

# %%
matrix[0][2]
# Out:
# 3
