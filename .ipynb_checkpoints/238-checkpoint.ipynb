# %%
nums = [1,2,3,4]
output , length = [] , len(nums)
para = 1
for i in range(length) : 
    output.append(para)
    para = para * nums[i]
para = 1
for i in range(length-1,-1,-1) :
    output[i] = output[i] * para
    para = para * nums[i]
print output
# Out:
# [24, 12, 8, 6]
