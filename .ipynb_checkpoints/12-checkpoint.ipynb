# %%
dict = {'10': 'X', '50': 'L', '1': 'I', '5': 'V', '100': 'C', '500': 'D', '1000': 'M'}
out = ""
n = 1994
rank = 0

for i in range(10) :
    if not n / pow(10,i) :
        rank = i
        break
for i in range(1,(n / 1000)+1) :
    out += dict['1000']  
for i in range(rank-1,0,-1) :  
    n = n % pow(10,i)
    set = 0
    thisround = 
    if ((n / 100) + 1 ) % 5 == 0 :
        out = out + dict['100'] + dict[str(((n / 100) + 1)*100)]
    elif ((n / 100) + 1 ) >= 6 :
        out = out + dict['500']
        set = 1
    if set == 1 :
        for i in range(1,(n / 100)+1-(((n / 100))/5)*5) :
            out += dict['100']
n = n % 100
set = 0
if ((n / 10) + 1 ) % 5 == 0 :
    out = out + dict['10'] + dict[str(((n / 10) + 1)*10)]
elif ((n / 10) + 1 ) >= 6 :
    out = out + dict['50']
    set = 1
if set == 1 :
    for i in range(1,(n / 10)+1-(((n / 10))/5)*5) :
        out += dict['10']
n = n % 10
set = 0
if ((n / 1) + 1 ) % 5 == 0 :
    out = out + dict['1'] + dict[str((n / 1) + 1)]
elif ((n / 1) + 1 ) >= 6 :
    out = out + dict['5']
    set = 1
if set == 1 :
    for i in range(1,(n / 1)+1-(((n / 1))/5)*5) :
        out += dict['1']
print rank
print out
# Out:
# 4
# MCMXCIV
