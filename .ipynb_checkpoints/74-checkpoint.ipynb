# %%
matrix = [[1,   3,  5,  7],[10, 11, 16, 20],[23, 30, 34, 50]]
target = 1
out = False
for x in range(len(matrix)) :
    if target in matrix[x] : out = True
print out
# Out:
# True

# %%
matrix = [[1,   3,  5,  7],[10, 11, 16, 20],[23, 30, 34, 50]]
for i in matrix :
    print i
# Out:
# [1, 3, 5, 7]
# [10, 11, 16, 20]
# [23, 30, 34, 50]

# %%
print matrix[0][0]
# Out:
# 1
