# %%
nums1 = [1, 2, 2, 1]
nums2 = [2, 2]
outlist = []
[large ,mini] = [nums1 , nums2] if len(nums1) > len(nums2) else [nums2 , nums1]
for element in mini :
    if element in large and element not in outlist :
        outlist.append(element)
print outlist
# Out:
# [2]
