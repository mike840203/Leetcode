# %%
nums = [-1,4,2,3]
thisnum = -1000
out = 0
for i in range(len(nums)-1) :
    if nums[i] > nums[i+1] or thisnum > nums[i]:
        nums[i+1] = thisnum if thisnum != -1000 else nums[i+1]
        out = out + 1
    else :
        thisnum = max(thisnum,nums[i])
print nums
print thisnum
print out
print True if out < 2 else False
# Out:
# [-1, 4, -1, 3]
# -1
# 1
# True
