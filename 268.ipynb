# %%
nums = [0,1]
nums.sort()
if nums[-1] != len(nums) : 
    print len(nums)
for i in range(max(nums)) :
    if nums[0] != 0 :
        print 0
    elif nums[i] != i :
        print i
# Out:
# 2

# %%
nums = [0]
print ((1+len(nums))*len(nums)) / 2 - sum(nums)
# Out:
# 1
