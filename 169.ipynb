# %%
nums = [2,2,5,5,14,6,654,654,5,5,584,2,8]
dict = {}
ma = 0 
index = 0
if len(nums) == 1 : return nums[0]
for x in nums:
    if x not in dict :
        dict[x] = 1
    else :
        dict[x] += 1
        if ma < dict[x] :
            ma = dict[x]
            index = x
print dict
print index
# Out:
# {2: 3, 5: 4, 6: 1, 584: 1, 14: 1, 8: 1, 654: 2}
# 5
