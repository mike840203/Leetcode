# %%
letters = ["c", "f", "j"]
target = "z"
target = ord(target)
output = 200
for i in range(len(letters)) :
    letters[i] = ord(letters[i])
    if letters[i] > target and letters[i] < output:
        output = letters[i]
if output > ord('z') :
    output = letters[0]
print chr(output)
# Out:
# c

# %%
letters = ["c", "f", "j","a","d"]
target = "a"
def nextGreatestLetter(letters, target):
    seen = set(letters)
    for i in xrange(1, 26):
        cand = chr((ord(target) - ord('a') + i) % 26 + ord('a'))
        if cand in seen:
            print cand
nextGreatestLetter(letters,target)
# Out:
# set(['a', 'c', 'j', 'd', 'f'])
# c
# d
# f
# j
