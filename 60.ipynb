# %%
n = 3
k = 2

res = ''
nums = [i for i in range(1,n+1)]
k , factor = k-1 ,1
for i in range(1,n) :
    factor = factor * i
for i in range(n) :
    index = k / factor
    k = k % factor
    factor = factor / (n-i-1) if n-i-1 else 1
    res = res + str(nums[index])
    del nums[index]
print res
# Out:
# 132
