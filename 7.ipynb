# %%
class Solution(object):
    def reverse(self, x):
        sign = 1
        if type(x) == int :
            if x < 0 :
                sign = -1
                x = - x
            output = sign * int(str(x)[::-1])
            if  -pow(2,32)/2 < output < pow(2,32)/2 :
                print type(output)
                return output
            else :
                return 0
        else :
            return 0
