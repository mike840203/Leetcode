# %%
path = "/a//b////c/d//......./......//" + "/"
toggle = 0 # 0 for dot, 1 for alphabet
count = 0 
candidate = []
out = "/"
for index in range(len(path)) :
    if ord(path[index]) == 47 :
        if count == 2 and toggle == 0 :
            candidate = candidate[:-1]
        elif count > 2 and toggle == 0 :
            
        elif count != 0 and toggle == 1 :
            candidate.append(path[index-count:index])
            count = 0
        count = 0
    else :
        count += 1
        toggle = 0 if ord(path[index]) == 46 else 1
out = out + "/".join(candidate)
print out
# Out:
# /a/b/c/d
