# %%
numRows = 4
i = 1
out = []
if out == [] :
    out.append([1])
while i < numRows :
    temp = [a for a in out[i-1]]
    for x in range(1,i+1) :
        if x == i :
            temp.append(1)
        else :
            temp[x] = out[i-1][x-1] + out[i-1][x]
    out.append(temp)
    i = i + 1
print out
# Out:
# [[1], [1, 1], [1, 2, 1], [1, 3, 3, 1]]

# %%
out = [[2]]
x = out[0]
x[0] = 1
out.append(x)
print out
# Out:
# [[1], [1]]
