# %%
n = 11
n = bin(n)
head = n[2]
for i in range(2,len(n)) :
    if i % 2 == 0 and n[i] != head :
        print False
    elif i % 2 == 1 and n[i] == head :
        print False
print True
# Out:
# False
# True
