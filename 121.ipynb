# %%
prices = [7,1,5,3,6,4]
min , out = float('inf') , 0
for i in range(prices) :
    if min > i :
        min = i
    out = max(out,i - min)
print out
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-1923f9053137> in <module>()
#       1 prices = [7,1,5,3,6,4]
#       2 min , out = float('inf') , 0
# ----> 3 for i in range(prices) :
#       4     if min > i :
#       5         min = i
#
# TypeError: range() integer end argument expected, got list.
