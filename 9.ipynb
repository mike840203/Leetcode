# %%
x = str(2146412) 
y = 234432
if len(x) % 2 == 1 :
    length = (len(x)-1)/2
else :
    length = len(x)/2
    
for i in range(length) :
    if x[i] == x[len(x)-i-1] :
        if i == length - 1 :
            output = True
    else :
        output = False
print output
# Out:
# True
